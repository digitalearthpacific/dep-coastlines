# %%
from joblib import load

from dask.distributed import Client
import odc.geo.xr
import pandas as pd
from dea_tools.spatial import subpixel_contours

from dep_coastlines.clean_rasters import Cleaner, calculate_consensus_land, remove_disconnected_land
from dep_coastlines.MosaicLoader import MultiyearMosaicLoader

# %%
cleaner = Cleaner()

# %%
loader = MultiyearMosaicLoader(start_year=1999, end_year=2023, version="0.6.0.4")

cell = (62, 30)
df = pd.DataFrame([cell])
df.index = [cell]
ds = loader.load(df)
ds
# Out:
# <xarray.Dataset>
# Dimensions:          (x: 748, y: 953, year: 6)
# Coordinates:
#     band             int64 1
#   * x                (x) float64 7.221e+05 7.222e+05 ... 7.445e+05 7.445e+05
#   * y                (y) float64 -9.297e+05 -9.298e+05 ... -9.583e+05 -9.583e+05
#     spatial_ref      int64 0
#   * year             (year) <U4 '2017' '2018' '2019' '2020' '2021' '2022'
# Data variables: (12/60)
#     blue             (year, y, x) float32 dask.array<chunksize=(1, 953, 748), meta=np.ndarray>
#     blue_mad         (year, y, x) float32 dask.array<chunksize=(1, 953, 748), meta=np.ndarray>
#     count            (year, y, x) float32 dask.array<chunksize=(1, 953, 748), meta=np.ndarray>
#     green            (year, y, x) float32 dask.array<chunksize=(1, 953, 748), meta=np.ndarray>
#     green_mad        (year, y, x) float32 dask.array<chunksize=(1, 953, 748), meta=np.ndarray>
#     nir08            (year, y, x) float32 dask.array<chunksize=(1, 953, 748), meta=np.ndarray>
#     ...               ...
#     mndwi_all        (y, x) float32 dask.array<chunksize=(953, 748), meta=np.ndarray>
#     ndwi_all         (y, x) float32 dask.array<chunksize=(953, 748), meta=np.ndarray>
#     nirwi_all        (y, x) float32 dask.array<chunksize=(953, 748), meta=np.ndarray>
#     meanwi_all       (y, x) float32 dask.array<chunksize=(953, 748), meta=np.ndarray>
#     wix_all          (y, x) float32 dask.array<chunksize=(953, 748), meta=np.ndarray>
#     maxwi_all        (y, x) float32 dask.array<chunksize=(953, 748), meta=np.ndarray>

# %%
with Client():
    output = cleaner.model.apply_mask(ds)
# Out:
# predicting...
# predicting...
# predicting...
# predicting...
# predicting...
# predicting...
# predicting...
# predicting...
# predicting...
# predicting...
# predicting...
# predicting...
# /home/jesse/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: divide by zero encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jesse/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: divide by zero encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jesse/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jesse/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: divide by zero encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jesse/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jesse/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: divide by zero encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jesse/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jesse/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jesse/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/dask/utils.py:73: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jesse/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/dask/utils.py:73: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jesse/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/dask/utils.py:73: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/xarray/core/dataset.py in ?(self, name)
#    1452             variable = self._variables[name]
#    1453         except KeyError:
# -> 1454             _, name, variable = _get_virtual_variable(self._variables, name, self.sizes)
#    1455
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/xarray/core/dataset.py in ?(self, key)
#    1553                 return self._construct_dataarray(key)
#    1554             except KeyError as e:
# -> 1555                 raise KeyError(
#    1556                     f"No variable named {key!r}. Variables on the dataset include {shorten_list_repr(list(self.variables.keys()), max_items=10)}"
#
# ~/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/xarray/core/dataset.py in ?(self, name)
#    1452             variable = self._variables[name]
#    1453         except KeyError:
# -> 1454             _, name, variable = _get_virtual_variable(self._variables, name, self.sizes)
#    1455
#
# ~/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/xarray/core/dataset.py in ?(variables, key, dim_sizes)
#     212
#     213     if not isinstance(key, str):
# --> 214         raise KeyError(key)
#     215
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_124585/1040609556.py in ?()
#       1 with Client():
#       2     output = cleaner.model.apply_mask(ds)
# ----> 3     ras, lines, roc = cleaner.process(output)
#
# ~/Projects/D4D/dep-coastlines/dep_coastlines/clean_rasters.py in ?(self, input)
#     184             output[self.water_index]
#     185         )
#     186
#     187         candidate_land = self.land(output)
# --> 188         consensus_land = calculate_consensus_land(input[0].isel(year=0)).compute()
#     189         # Connected areas are contiguous zones that are connected in some way to
#     190         # the consensus areas. This ensures that all edges of these (on the basis of nir)
#     191         # are included
#
# ~/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/xarray/core/dataset.py in ?(self, key)
#    1551         if utils.hashable(key):
#    1552             try:
#    1553                 return self._construct_dataarray(key)
#    1554             except KeyError as e:
# -> 1555                 raise KeyError(
#    1556                     f"No variable named {key!r}. Variables on the dataset include {shorten_list_repr(list(self.variables.keys()), max_items=10)}"
#    1557                 ) from e
#    1558
#
# KeyError: "No variable named 0. Variables on the dataset include ['blue', 'blue_mad', 'count', 'green', 'green_mad', ..., 'band', 'x', 'y', 'spatial_ref', 'year']"

# %%
import folium
m = output.sel(year='2018').nir08.odc.explore(layer_control=False)
m = ds.sel(year='2018').nir08.odc.explore(map=m)
#folium.LayerControl().add_to(m) 
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa5bb1acce669df2c12911d7cc302e9f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa5bb1acce669df2c12911d7cc302e9f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa5bb1acce669df2c12911d7cc302e9f = L.map(
#                 &quot;map_fa5bb1acce669df2c12911d7cc302e9f&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1cea7b1b8036a6ffd6dbbf20b4564dce = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fa5bb1acce669df2c12911d7cc302e9f);
#
#
#             var image_overlay_d3d8f863c1956a1e26b769c33cf2eb82 = L.imageOverlay(
#                 &quot;...

# %%
output.sel(year="2018").rio.to_raster('../masked6230.tif')

# %%
candidate_land = cleaner.land(output)
consensus_land = calculate_consensus_land(ds.isel(year=1)).compute()
connected_areas = remove_disconnected_land(consensus_land, candidate_land.compute())
connected_areas.astype(int).sel(year='2018').odc.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c1c52d526bf024173540fd05fed4918 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c1c52d526bf024173540fd05fed4918&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1c1c52d526bf024173540fd05fed4918 = L.map(
#                 &quot;map_1c1c52d526bf024173540fd05fed4918&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_39ff5c3d2899c08ae60fd24514909358 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1c1c52d526bf024173540fd05fed4918);
#
#
#             var image_overlay_77f0a3f6b99ffe1ea0136f0228d04b6a = L.imageOverlay(
#                 &quot;...&quot;,
#                 [[-8.404306363239211, 179.01697525277743], [-8.664420359706888, 179.22286911589762]],
#                 {}
#             ).addTo(map_1c1c52d526bf024173540fd05fed4918);
#
#
#             map_1c1c52d526bf024173540fd05fed4918.fitBounds(
#                 [[-8.405647478757688, 179.01722035924809], [-8.66296026649524, 179.22241195034104]],
#                 {}
#             );
#
#
#             var layer_control_03ea26de1215dfc976bb0f5a23aecf11 = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_39ff5c3d2899c08ae60fd24514909358,
#                 },
#                 overlays :  {
#                     &quot;meanwi&quot; : image_overlay_77f0a3f6b99ffe1ea0136f0228d04b6a,
#                 },
#             };
#             L.control.layers(
#                 layer_control_03ea26de1215dfc976bb0f5a23aecf11.base_layers,
#                 layer_control_03ea26de1215dfc976bb0f5a23aecf11.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_1c1c52d526bf024173540fd05fed4918);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import xrspatial as xs
no_connected_neighbors = xs.focal.mean(consensus_land) == 0
suspicious_connected_areas = candidate_land & no_connected_neighbors
analysis_zone = connected_areas & ~suspicious_connected_areas
analysis_zone.sel(year='2018').astype(int).odc.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb63bbe3656492fbea07a73e4e3fe431 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb63bbe3656492fbea07a73e4e3fe431&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb63bbe3656492fbea07a73e4e3fe431 = L.map(
#                 &quot;map_bb63bbe3656492fbea07a73e4e3fe431&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5762f525655369d5e145b7fc92b41f41 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bb63bbe3656492fbea07a73e4e3fe431);
#
#
#             var image_overlay_2f3321fca82a398ad134c2d383b674d0 = L.imageOverlay(
#                 &quot;...&quot;,
#                 [[-8.404306363239211, 179.01697525277743], [-8.664420359706888, 179.22286911589762]],
#                 {}
#             ).addTo(map_bb63bbe3656492fbea07a73e4e3fe431);
#
#
#             map_bb63bbe3656492fbea07a73e4e3fe431.fitBounds(
#                 [[-8.405647478757688, 179.01722035924809], [-8.66296026649524, 179.22241195034104]],
#                 {}
#             );
#
#
#             var layer_control_fc2cb68b09a36afff32cf5feaf24503d = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_5762f525655369d5e145b7fc92b41f41,
#                 },
#                 overlays :  {
#                     &quot;macro_element_2f3321fca82a398ad134c2d383b674d0&quot; : image_overlay_2f3321fca82a398ad134c2d383b674d0,
#                 },
#             };
#             L.control.layers(
#                 layer_control_fc2cb68b09a36afff32cf5feaf24503d.base_layers,
#                 layer_control_fc2cb68b09a36afff32cf5feaf24503d.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_bb63bbe3656492fbea07a73e4e3fe431);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
analysis_zone = cleaner.expand_analysis_zone(analysis_zone, output)
# analysis_zone.sel(year='2018').astype(int).rio.to_raster('../azone.tif')
# Out:
# predicting...
# predicting...
# predicting...
# predicting...
# predicting...
# predicting...
# /home/jesse/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: divide by zero encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jesse/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: divide by zero encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jesse/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: divide by zero encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jesse/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jesse/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jesse/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: divide by zero encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jesse/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /home/jesse/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/dask/utils.py:73: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jesse/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/dask/utils.py:73: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jesse/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/dask/utils.py:73: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jesse/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/dask/utils.py:73: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# /home/jesse/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/dask/utils.py:73: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/xarray/core/dataset.py in ?(self, name)
#    1452             variable = self._variables[name]
#    1453         except KeyError:
# -> 1454             _, name, variable = _get_virtual_variable(self._variables, name, self.sizes)
#    1455
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/xarray/core/dataset.py in ?(self, key)
#    1553                 return self._construct_dataarray(key)
#    1554             except KeyError as e:
# -> 1555                 raise KeyError(
#    1556                     f"No variable named {key!r}. Variables on the dataset include {shorten_list_repr(list(self.variables.keys()), max_items=10)}"
#
# ~/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/xarray/core/dataset.py in ?(self, name)
#    1452             variable = self._variables[name]
#    1453         except KeyError:
# -> 1454             _, name, variable = _get_virtual_variable(self._variables, name, self.sizes)
#    1455
#
# ~/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/xarray/core/dataset.py in ?(variables, key, dim_sizes)
#     212
#     213     if not isinstance(key, str):
# --> 214         raise KeyError(key)
#     215
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_124585/3144960704.py in ?()
#       1 analysis_zone = cleaner.expand_analysis_zone(analysis_zone, output)
#       2 # analysis_zone.sel(year='2018').astype(int).rio.to_raster('../azone.tif')
#       3 with Client():
# ----> 4     ras, lines, roc = cleaner.process(output)
#
# ~/Projects/D4D/dep-coastlines/dep_coastlines/clean_rasters.py in ?(self, input)
#     184             output[self.water_index]
#     185         )
#     186
#     187         candidate_land = self.land(output)
# --> 188         consensus_land = calculate_consensus_land(input[0].isel(year=0)).compute()
#     189         # Connected areas are contiguous zones that are connected in some way to
#     190         # the consensus areas. This ensures that all edges of these (on the basis of nir)
#     191         # are included
#
# ~/Projects/D4D/dep-coastlines/venv/lib/python3.10/site-packages/xarray/core/dataset.py in ?(self, key)
#    1551         if utils.hashable(key):
#    1552             try:
#    1553                 return self._construct_dataarray(key)
#    1554             except KeyError as e:
# -> 1555                 raise KeyError(
#    1556                     f"No variable named {key!r}. Variables on the dataset include {shorten_list_repr(list(self.variables.keys()), max_items=10)}"
#    1557                 ) from e
#    1558
#
# KeyError: "No variable named 0. Variables on the dataset include ['blue', 'blue_mad', 'count', 'green', 'green_mad', ..., 'band', 'x', 'y', 'spatial_ref', 'year']"

# %%
def water(xr):
    return output.meanwi >= 0

from odc.algo import mask_cleanup
from dep_coastlines.raster_cleaning import load_gadm_land, find_inland_areas
gadm_land = load_gadm_land(output)

land = gadm_land | consensus_land
ocean = mask_cleanup(~land, mask_filters=[("erosion", 2)])
inland_areas = find_inland_areas(water(output), ocean)
inland_areas.sel(year="2018").astype(int).odc.explore()

toutput = (
            output.meanwi
            .where(analysis_zone, 0.5)
            .where(~inland_areas)
        )

toutput.groupby("year").map(xs.focal.mean).sel(year='2018').odc.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce977767a49dfc1cc25f42daea4dc7ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce977767a49dfc1cc25f42daea4dc7ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ce977767a49dfc1cc25f42daea4dc7ce = L.map(
#                 &quot;map_ce977767a49dfc1cc25f42daea4dc7ce&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_22ad8eaa835ddcf755ba1f03103c6387 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ce977767a49dfc1cc25f42daea4dc7ce);
#
#
#             var image_overlay_9fb87c784589d686c925b6f088e42c9a = L.imageOverlay(
#                 &quot;...

# %%
ocean = ~land
mask_cleanup(land, mask_filters=[("closing", 20)]).odc.explore()
# ocean.odc.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ca9259f7ac69501b765852e15a5b8a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ca9259f7ac69501b765852e15a5b8a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4ca9259f7ac69501b765852e15a5b8a7 = L.map(
#                 &quot;map_4ca9259f7ac69501b765852e15a5b8a7&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_92208d244051cde534f1684629f87bca = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4ca9259f7ac69501b765852e15a5b8a7);
#
#
#             var image_overlay_86a9a03ff30cdef9cfe29ec0295d7535 = L.imageOverlay(
#                 &quot;...

# %%
cleaner.water(output.sel(year='2022')).odc.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_725116748b62dfbad76958c209b367cc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_725116748b62dfbad76958c209b367cc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_725116748b62dfbad76958c209b367cc = L.map(
#                 &quot;map_725116748b62dfbad76958c209b367cc&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1a669e70d43fe5d3335537b4594de429 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_725116748b62dfbad76958c209b367cc);
#
#
#             var image_overlay_40d768dcf477831927ddbee933042801 = L.imageOverlay(
#                 &quot;...

# %%
inland_areas = find_inland_areas(cleaner.water(output), ocean)
inland_areas.sel(year='2022').astype(int).odc.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_08f2d5c359b0930ed967e9e06c3257e8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_08f2d5c359b0930ed967e9e06c3257e8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_08f2d5c359b0930ed967e9e06c3257e8 = L.map(
#                 &quot;map_08f2d5c359b0930ed967e9e06c3257e8&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_503ed12aa020b05a17242e37d1faa3cb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_08f2d5c359b0930ed967e9e06c3257e8);
#
#
#             var image_overlay_74df5e106e21841bc2f0162b267d3d5d = L.imageOverlay(
#                 &quot;...

# %%
analysis_zone = analysis_zone | mask_cleanup(cleaner.land(output.where(analysis_zone)), mask_filters=[("dilation", 1)])
# output.ndwi.where(analysis_zone).sel(year='2022').odc.explore()

output.ndwi.where(analysis_zone, 0.5).rio.to_raster('../o5.tif')

# %%
combined_gdf = subpixel_contours(
    output.ndwi.where(analysis_zone, 0.5),
    dim="year",
    z_values=[cleaner.index_threshold],
    min_vertices=5,
)
combined_gdf.explore()

combined_gdf.to_file('c5.gpkg')
# Out:
# Loading data into memory using Dask
# Operating in single z-value, multiple arrays mode

# %%
output = output['ndwi'].where(analysis_zone, 0.5).compute()
output.sel(year='2022').odc.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e61a3307c50b1ba6ee9c8159573efd63 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e61a3307c50b1ba6ee9c8159573efd63&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e61a3307c50b1ba6ee9c8159573efd63 = L.map(
#                 &quot;map_e61a3307c50b1ba6ee9c8159573efd63&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d8a8e27a90f80d88c5b8e028dfd5e4e9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e61a3307c50b1ba6ee9c8159573efd63);
#
#
#             var image_overlay_bf78dda86863fb69f02dbd7ef1d22ff3 = L.imageOverlay(
#                 &quot;...

# %%
#output = (
#    output[cleaner.water_index]
#    .where(analysis_zone, obvious_water)
#    .where(~inland_areas)
#)
#output = output.groupby("year").map(xs.focal.mean)
combined_gdf = subpixel_contours(
    output,
    dim="year",
    z_values=[cleaner.index_threshold],
    min_vertices=5,
)
combined_gdf.explore()
# Out:
# Operating in single z-value, multiple arrays mode
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0def294c0790ef57c2bdd72147cf934b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0def294c0790ef57c2bdd72147cf934b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0def294c0790ef57c2bdd72147cf934b = L.map(
#                 &quot;map_0def294c0790ef57c2bdd72147cf934b&quot;,
#                 {
#                     center: [-22.44295697799835, 166.6136711525898],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0def294c0790ef57c2bdd72147cf934b);
#
#
#
#
#
#             var tile_layer_3df9ff7b7b7e0d63ce87779047271c0e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0def294c0790ef57c2bdd72147cf934b);
#
#
#             map_0def294c0790ef57c2bdd72147cf934b.fitBounds(
#                 [[-22.84720212394072, 166.16523630168854], [-22.038711832055984, 167.06210600349104]],
#                 {}
#             );
#
#
#         function geo_json_d4089bd2d95a56890eea49d5e291ee9e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_d4089bd2d95a56890eea49d5e291ee9e_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_d4089bd2d95a56890eea49d5e291ee9e_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_d4089bd2d95a56890eea49d5e291ee9e_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_d4089bd2d95a56890eea49d5e291ee9e_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_d4089bd2d95a56890eea49d5e291ee9e.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_d4089bd2d95a56890eea49d5e291ee9e_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_d4089bd2d95a56890eea49d5e291ee9e = L.geoJson(null, {
#                 onEachFeature: geo_json_d4089bd2d95a56890eea49d5e291ee9e_onEachFeature,
#
#                 style: geo_json_d4089bd2d95a56890eea49d5e291ee9e_styler,
#                 pointToLayer: geo_json_d4089bd2d95a56890eea49d5e291ee9e_pointToLayer
#         });
#
#         function geo_json_d4089bd2d95a56890eea49d5e291ee9e_add (data) {
#             geo_json_d4089bd2d95a56890eea49d5e291ee9e
#                 .addData(data)
#                 .addTo(map_0def294c0790ef57c2bdd72147cf934b);
#         }
#             geo_json_d4089bd2d95a56890eea49d5e291ee9e_add({&quot;bbox&quot;: [166.16523630168854, -22.84720212394072, 167.06210600349104, -22.038711832055984], &quot;features&quot;: [{&quot;bbox&quot;: [166.16523630168854, -22.847201706046036, 167.04009555973425, -22.038711832055984], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[166.16523630168854, -22.038711832055984], [166.16552707565734, -22.038723986404463], [166.1656861020191, -22.038883027593574], [166.1657042221316, -22.03915389377761], [166.16570254766728, -22.03942490085882], [166.16568639601803, -22.03969601098874], [166.16569734235975, -22.039966928211093], [166.16574828254474, -22.040237560708988]], [[166.1669298106612
